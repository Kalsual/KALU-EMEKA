# %%
#importing the library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset
df = pd.read_csv(r"C:\Users\personal\Documents\HAMOYE\fuel_ferc1.txt")

# %%
df
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# 6         f1_fuel_1994_12_2_1_1                 2         1994
# 7        f1_fuel_1994_12_2_1_10                 2         1994
# 8        f1_fuel_1994_12_2_2_10                 2         1994
# 9         f1_fuel_1994_12_4_0_1                 4         1994
# 10        f1_fuel_1994_12_4_0_2                 4         1994
# 11        f1_fuel_1994_12_4_0_4                 4         1994
# 12        f1_fuel_1994_12_4_0_5                 4         1994
# 13        f1_fuel_1994_12_6_0_1                 6         1994
# ...

# %%
#showing first 5 data
df.head(5)
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
#checking and suming missing value
df.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
#checking for summary statistics
df.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
#checking for dupicates
df.duplicated().any()
# Out:
# False

# %%
#shape of dataset
df.shape
# Out:
# (29523, 11)

# %%
#type of dataset
df.dtypes
# Out:
# record_id                        object
# utility_id_ferc1                  int64
# report_year                       int64
# plant_name_ferc1                 object
# fuel_type_code_pudl              object
# fuel_unit                        object
# fuel_qty_burned                 float64
# fuel_mmbtu_per_unit             float64
# fuel_cost_per_unit_burned       float64
# fuel_cost_per_unit_delivered    float64
# fuel_cost_per_mmbtu             float64
# dtype: object

# %%
#potting to see corr
sns.heatmap(df.corr(), annot = True, fmt= ".0%")

# %%
#Groupby to count unique values
df.groupby("fuel_unit")["fuel_unit"].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
#filling the nan values in the fuel_unit
df[["fuel_unit"]] = df[['fuel_unit']].fillna(value = "gal")

# %%
#ascertaining the values after filling nan
df.groupby("fuel_unit")["fuel_unit"].count()
# Out:
# fuel_unit
# bbl        7998
# gal         264
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
df.groupby("fuel_type_code_pudl")["fuel_type_code_pudl"].count()
# Out:
# fuel_type_code_pudl
# coal        8547
# gas        11486
# nuclear      818
# oil         8064
# other        167
# waste        441
# Name: fuel_type_code_pudl, dtype: int64

# %%
df1 = df.groupby(["report_year","fuel_type_code_pudl"])["fuel_cost_per_unit_burned"].mean()
df1
# Out:
# report_year  fuel_type_code_pudl
# 1994         coal                      31.546467
#              gas                       22.161183
#              nuclear                 3211.033155
#              oil                       56.398759
#              other                      9.728083
#              waste                      2.198417
# 1995         coal                      30.677442
#              gas                       18.067406
#              nuclear                 5262.364918
#              oil                      158.037885
#              other                     12.238467
#              waste                     -8.759045
# 1996         coal                      29.454299
#              gas                        3.444577
#              nuclear                 1625.802122
#              oil                       33.481425
#              other                     20.009375
#              waste                      4.004182
# ...

# %% [markdown]
# # Correlation Coefficient

# %%
df.corr().loc["fuel_qty_burned"].sort_values(ascending = False)
# Out:
# fuel_qty_burned                 1.000000
# report_year                     0.012952
# fuel_cost_per_mmbtu            -0.001896
# fuel_cost_per_unit_delivered   -0.003551
# fuel_cost_per_unit_burned      -0.018535
# utility_id_ferc1               -0.057447
# fuel_mmbtu_per_unit            -0.080946
# Name: fuel_qty_burned, dtype: float64

# %%
#sum of total fuel quantity burned for coal in 2002
df.loc[(df["report_year"]== 2002) & (df["fuel_type_code_pudl"] == "coal"), "fuel_qty_burned"].sum()
# Out:
# 814435715.0

# %%
df.groupby("report_year")["fuel_cost_per_unit_burned"].mean().sort_values()
# Out:
# report_year
# 1996     79.434995
# 2002    101.179365
# 2005    107.111221
# 1999    120.053605
# 2003    123.183919
# 1998    126.683519
# 2001    133.013010
# 1997    149.482132
# 2006    151.361249
# 2004    154.897398
# 2007    202.622082
# 1994    213.191996
# 2009    215.699318
# 2018    232.992036
# 2000    237.797111
# 2015    237.933197
# 2017    246.281796
# 2016    247.083959
# 2008    255.954415
# 2013    255.991023
# 2012    258.804138
# 2010    262.951203
# 2011    301.754519
# 1995    354.422555
# 2014    442.359068
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
df.corr().loc["fuel_qty_burned"].sort_values(ascending = False)
# Out:
# fuel_qty_burned                 1.000000
# report_year                     0.012952
# fuel_cost_per_mmbtu            -0.001896
# fuel_cost_per_unit_delivered   -0.003551
# fuel_cost_per_unit_burned      -0.018535
# utility_id_ferc1               -0.057447
# fuel_mmbtu_per_unit            -0.080946
# Name: fuel_qty_burned, dtype: float64

# %%
#fuel types per unit burned
df.groupby("fuel_type_code_pudl")["fuel_cost_per_unit_burned"].mean().sort_values()
# Out:
# fuel_type_code_pudl
# gas          13.659397
# other        18.253856
# waste        19.518122
# coal         67.421830
# oil         168.877086
# nuclear    4955.157002
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
#std dev
std_dev = df["fuel_mmbtu_per_unit"].std()
std_dev
# Out:
# 10.600220307806886

# %%
#75th percentile
perc = df["fuel_mmbtu_per_unit"].quantile(q=0.75)
perc
# Out:
# 17.006

# %%
#skewness of fuell quality
df["fuel_qty_burned"].skew()
# Out:
# 15.851495469109503

# %%
#kurtois
df["fuel_qty_burned"].kurt()
# Out:
# 651.3694501337732
